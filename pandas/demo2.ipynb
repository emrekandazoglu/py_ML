# %%
import pandas as pd

# %%
df=pd.read_csv('../04 PANDAS\pokemon.csv')

# %%
df
# Out:
#        #                 Name   Type 1  Type 2  Total   HP  Attack  Defense  \
# 0      1            Bulbasaur    Grass  Poison    318   45      49       49
# 1      2              Ivysaur    Grass  Poison    405   60      62       63
# 2      3             Venusaur    Grass  Poison    525   80      82       83
# 3      4           Charmander     Fire     NaN    309   39      52       43
# 4      5           Charmeleon     Fire     NaN    405   58      64       58
# ..   ...                  ...      ...     ...    ...  ...     ...      ...
# 737  738              Zygarde   Dragon  Ground    600  108     100      121
# 738  739              Diancie     Rock   Fairy    600   50     100      150
# 739  740  HoopaHoopa Confined  Psychic   Ghost    600   80     110       60
# 740  741   HoopaHoopa Unbound  Psychic    Dark    680   80     160       60
# 741  742            Volcanion     Fire   Water    600   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.head(10)
# Out:
#     #        Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0   1   Bulbasaur  Grass  Poison    318  45      49       49       65
# 1   2     Ivysaur  Grass  Poison    405  60      62       63       80
# 2   3    Venusaur  Grass  Poison    525  80      82       83      100
# 3   4  Charmander   Fire     NaN    309  39      52       43       60
# 4   5  Charmeleon   Fire     NaN    405  58      64       58       80
# 5   6   Charizard   Fire  Flying    534  78      84       78      109
# 6   7    Squirtle  Water     NaN    314  44      48       65       50
# 7   8   Wartortle  Water     NaN    405  59      63       80       65
# 8   9   Blastoise  Water     NaN    530  79      83      100       85
# 9  10    Caterpie    Bug     NaN    195  45      30       35       20
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# ...

# %%
df.tail()
# Out:
#        #                 Name   Type 1  Type 2  Total   HP  Attack  Defense  \
# 737  738              Zygarde   Dragon  Ground    600  108     100      121
# 738  739              Diancie     Rock   Fairy    600   50     100      150
# 739  740  HoopaHoopa Confined  Psychic   Ghost    600   80     110       60
# 740  741   HoopaHoopa Unbound  Psychic    Dark    680   80     160       60
# 741  742            Volcanion     Fire   Water    600   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 737       81       95     95           6       True
# 738      100      150     50           6       True
# 739      150      130     70           6       True
# 740      170      130     80           6       True
# 741      130       90     70           6       True

# %%
df.describe().transpose()
# Out:
#             count        mean         std    min     25%    50%     75%    max
# #           742.0  371.500000  214.341239    1.0  186.25  371.5  556.75  742.0
# Total       742.0  422.711590  111.899320  180.0  325.00  430.0  500.00  720.0
# HP          742.0   68.699461   25.979645    1.0   50.00   65.0   80.00  255.0
# Attack      742.0   75.803235   29.657225    5.0   55.00   75.0   95.00  180.0
# Defense     742.0   71.439353   29.467766    5.0   50.00   67.0   89.75  230.0
# Sp. Atk     742.0   70.113208   29.979536   10.0   45.25   65.0   90.00  180.0
# Sp. Def     742.0   70.088949   27.308952   20.0   50.00   65.0   85.00  230.0
# Speed       742.0   66.567385   27.899185    5.0   45.00   65.0   86.75  180.0
# Generation  742.0    3.358491    1.660302    1.0    2.00    3.0    5.00    6.0

# %%
len(df)
# Out:
# 742

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df[['Name','Type 1']]
# Out:
#                     Name   Type 1
# 0              Bulbasaur    Grass
# 1                Ivysaur    Grass
# 2               Venusaur    Grass
# 3             Charmander     Fire
# 4             Charmeleon     Fire
# ..                   ...      ...
# 737              Zygarde   Dragon
# 738              Diancie     Rock
# 739  HoopaHoopa Confined  Psychic
# 740   HoopaHoopa Unbound  Psychic
# 741            Volcanion     Fire
#
# [742 rows x 2 columns]

# %%
df['total atk']=df['Attack']+df['Sp. Atk']
#tabloya total atak columu eklendi

# %%
df.head()
# Out:
#    #        Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2  3    Venusaur  Grass  Poison    525  80      82       83      100      100
# 3  4  Charmander   Fire     NaN    309  39      52       43       60       50
# 4  5  Charmeleon   Fire     NaN    405  58      64       58       80       65
#
#    Speed  Generation  Legendary  total ark  total atk
# 0     45           1      False        114        114
# 1     60           1      False        142        142
# 2     80           1      False        182        182
# 3     65           1      False        112        112
# 4     80           1      False        144        144

# %%
df['hp ratio %']=round(100*df['HP']/df['Defense'],2)

# %%
df.head()
# Out:
#    #        Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2  3    Venusaur  Grass  Poison    525  80      82       83      100      100
# 3  4  Charmander   Fire     NaN    309  39      52       43       60       50
# 4  5  Charmeleon   Fire     NaN    405  58      64       58       80       65
#
#    Speed  Generation  Legendary  total ark  total atk
# 0     45           1      False        114        114
# 1     60           1      False        142        142
# 2     80           1      False        182        182
# 3     65           1      False        112        112
# 4     80           1      False        144        144

# %%
df.drop('hp ratio %',axis=1).head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\emrek\Masaüstü\py_ML\pandas\demo2.ipynb Cell 14 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/emrek/Masa%C3%BCst%C3%BC/py_ML/pandas/demo2.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> df.drop('hp ratio %',axis=1).head()
#
# File c:\Users\emrek\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\emrek\anaconda3\lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
df
# Out:
#        #                 Name   Type 1  Type 2  Total   HP  Attack  Defense  \
# 0      1            Bulbasaur    Grass  Poison    318   45      49       49
# 1      2              Ivysaur    Grass  Poison    405   60      62       63
# 2      3             Venusaur    Grass  Poison    525   80      82       83
# 3      4           Charmander     Fire     NaN    309   39      52       43
# 4      5           Charmeleon     Fire     NaN    405   58      64       58
# ..   ...                  ...      ...     ...    ...  ...     ...      ...
# 737  738              Zygarde   Dragon  Ground    600  108     100      121
# 738  739              Diancie     Rock   Fairy    600   50     100      150
# 739  740  HoopaHoopa Confined  Psychic   Ghost    600   80     110       60
# 740  741   HoopaHoopa Unbound  Psychic    Dark    680   80     160       60
# 741  742            Volcanion     Fire   Water    600   80     110      120
#
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
poke=df.iloc[148]
poke
# Out:
# #                 149
# Name           Mewtwo
# Type 1        Psychic
# Type 2            NaN
# Total             680
# HP                106
# Attack            110
# Defense            90
# Sp. Atk           154
# Sp. Def            90
# Speed             130
# Generation          1
# Legendary        True
# total ark         264
# total atk         264
# Name: 148, dtype: object

# %%
type(poke)
# Out:
# pandas.core.series.Series

# %%
df.drop([148],axis=0,inplace=True)
df[140:150]
# Out:
#        #        Name    Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 140  141  Aerodactyl      Rock  Flying    515   80     105       65       60
# 141  142     Snorlax    Normal     NaN    540  160     110       65       65
# 142  143    Articuno       Ice  Flying    580   90      85      100       95
# 143  144      Zapdos  Electric  Flying    580   90      90       85      125
# 144  145     Moltres      Fire  Flying    580   90     100       90      125
# 145  146     Dratini    Dragon     NaN    300   41      64       45       50
# 146  147   Dragonair    Dragon     NaN    420   61      84       65       70
# 147  148   Dragonite    Dragon  Flying    600   91     134       95      100
# 149  150         Mew   Psychic     NaN    600  100     100      100      100
# 150  151   Chikorita     Grass     NaN    318   45      49       65       49
#
#      Sp. Def  Speed  Generation  Legendary  total ark  total atk
# ...

# %%
df.append(poke).tail()
# Out:
# C:\Users\emrek\AppData\Local\Temp\ipykernel_11500\2139118000.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(poke).tail()
#        #                 Name   Type 1 Type 2  Total   HP  Attack  Defense  \
# 738  739              Diancie     Rock  Fairy    600   50     100      150
# 739  740  HoopaHoopa Confined  Psychic  Ghost    600   80     110       60
# 740  741   HoopaHoopa Unbound  Psychic   Dark    680   80     160       60
# 741  742            Volcanion     Fire  Water    600   80     110      120
# 148  149               Mewtwo  Psychic    NaN    680  106     110       90
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  total ark  total atk
# 738      100      150     50           6       True        200        200
# 739      150      130     70           6       True        260        260
# 740      170      130     80           6       True        330        330
# ...

# %%
try:
  df.iloc['abra']
  
except TypeError:
  print("Cannot index by location index with a non-integer key")
except:
  print("Something else went wrong")
df.iloc[1]
# Out:
# Cannot index by location index with a non-integer key
# #                   2
# Name          Ivysaur
# Type 1          Grass
# Type 2         Poison
# Total             405
# HP                 60
# Attack             62
# Defense            63
# Sp. Atk            80
# Sp. Def            80
# Speed              60
# Generation          1
# Legendary       False
# total ark         142
# total atk         142
# Name: 1, dtype: object

# %%
df=pd.read_csv('../04 PANDAS\pokemon.csv')
df.tail()
# Out:
#        #                 Name   Type 1  Type 2  Total   HP  Attack  Defense  \
# 737  738              Zygarde   Dragon  Ground    600  108     100      121
# 738  739              Diancie     Rock   Fairy    600   50     100      150
# 739  740  HoopaHoopa Confined  Psychic   Ghost    600   80     110       60
# 740  741   HoopaHoopa Unbound  Psychic    Dark    680   80     160       60
# 741  742            Volcanion     Fire   Water    600   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 737       81       95     95           6       True
# 738      100      150     50           6       True
# 739      150      130     70           6       True
# 740      170      130     80           6       True
# 741      130       90     70           6       True

# %%
df['HP']>100
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 737     True
# 738    False
# 739    False
# 740    False
# 741    False
# Name: HP, Length: 742, dtype: bool

# %%
df.iloc[737:741]
# Out:
#        #                 Name   Type 1  Type 2  Total   HP  Attack  Defense  \
# 737  738              Zygarde   Dragon  Ground    600  108     100      121
# 738  739              Diancie     Rock   Fairy    600   50     100      150
# 739  740  HoopaHoopa Confined  Psychic   Ghost    600   80     110       60
# 740  741   HoopaHoopa Unbound  Psychic    Dark    680   80     160       60
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 737       81       95     95           6       True
# 738      100      150     50           6       True
# 739      150      130     70           6       True
# 740      170      130     80           6       True

# %%
selected_rows = []

# Her bir satırı kontrol ederek filtreleme yapalım
for index, row in df.iterrows():
    if row['HP'] > 100:  # 'HP' sütunu değeri 50'den büyükse
        selected_rows.append(row)  # Şartı sağlayan satırları listeye ekle

# Yeni bir DataFrame oluşturmak için biriktirdiğimiz verileri kullanalım
new_df = pd.DataFrame(selected_rows)

# Yeni DataFrame'i görüntüleyelim
new_df

#bu zor olan yontem
# Out:
#        #        Name  Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 38    39  Jigglypuff  Normal   Fairy    270  115      45       20       45
# 39    40  Wigglytuff  Normal   Fairy    435  140      70       45       85
# 88    89         Muk  Poison     NaN    500  105     105       75       65
# 111  112      Rhydon  Ground    Rock    485  105     130      120       45
# 112  113     Chansey  Normal     NaN    450  250       5        5       35
# ..   ...         ...     ...     ...    ...  ...     ...      ...      ...
# 702  703  Aromatisse   Fairy     NaN    462  101      72       72       99
# 718  719     Aurorus    Rock     Ice    521  123      77       72       99
# 735  736     Xerneas   Fairy     NaN    680  126     131       95      131
# 736  737     Yveltal    Dark  Flying    680  126     131       95      131
# 737  738     Zygarde  Dragon  Ground    600  108     100      121       81
#
#      Sp. Def  Speed  Generation  Legendary
# ...

# %%
HP= df['HP']>150
df[HP]
# Out:
#        #       Name   Type 1 Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 112  113    Chansey   Normal    NaN    450  250       5        5       35
# 141  142    Snorlax   Normal    NaN    540  160     110       65       65
# 200  201  Wobbuffet  Psychic    NaN    405  190      33       58       33
# 240  241    Blissey   Normal    NaN    540  255      10       10       75
# 319  320    Wailord    Water    NaN    500  170      90       45       90
# 605  606  Alomomola    Water    NaN    470  165      75       80       40
#
#      Sp. Def  Speed  Generation  Legendary
# 112      105     50           1      False
# 141      110     30           1      False
# 200       58     33           2      False
# 240      135     55           2      False
# 319       45     60           3      False
# 605       45     65           5      False

# %%
df.iloc[100]
x=pd.DataFrame([df.iloc[100]])
x
df.iloc[100]
# Out:
# pandas.core.series.Series
