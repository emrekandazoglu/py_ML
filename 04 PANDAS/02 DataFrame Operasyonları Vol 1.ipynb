# %% [markdown]
# ## Data Frame Operasyonları
#
# Sh*t is About to Get Real

# %% [markdown]
# ### Import Files

# %% [markdown]
# Çok zor ama velevki komut çalışmadı
#
#     !pip install xlrd
#     !pip install openpyxl
#
# bunları bi çalıştırıp koşturuver.
# (editörü açıp kapatmayı unutma.)

# %% [markdown]
# ### Import Yöntemleri:
#
# 1. İçe aktarılacak dosya ve not defteri aynı dosyaının içinndeyse:
#
#         df = pd.read_csv("pokemon.csv")
#
# 2. Farklı dosyalarda ise:
#
#         df = pd.read_csv("C:\\Users\\mbatu\\Desktop\\Kumay\\DS 101\\04 PANDAS\\pokemon.csv")
#
#     **VEYA**
#
#         df = pd.read_csv("../data/pokemon.csv")

# %%
df = pd.read_csv("pokemon.csv")

# %% [markdown]
# Zamanı olan aşağıdaki linkten şu arkadaşa bi teşekkür yorumu yazabilir mi?
#
# https://gist.github.com/armgilles/194bcff35001e7eb53a2a8b441e8b2c6

# %%
df
# Out:
#        #                 Name   Type 1  Type 2  Total   HP  Attack  Defense  \
# 0      1            Bulbasaur    Grass  Poison    318   45      49       49
# 1      2              Ivysaur    Grass  Poison    405   60      62       63
# 2      3             Venusaur    Grass  Poison    525   80      82       83
# 3      4           Charmander     Fire     NaN    309   39      52       43
# 4      5           Charmeleon     Fire     NaN    405   58      64       58
# ..   ...                  ...      ...     ...    ...  ...     ...      ...
# 737  738              Zygarde   Dragon  Ground    600  108     100      121
# 738  739              Diancie     Rock   Fairy    600   50     100      150
# 739  740  HoopaHoopa Confined  Psychic   Ghost    600   80     110       60
# 740  741   HoopaHoopa Unbound  Psychic    Dark    680   80     160       60
# 741  742            Volcanion     Fire   Water    600   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.head()
# Out:
#    #        Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2  3    Venusaur  Grass  Poison    525  80      82       83      100      100
# 3  4  Charmander   Fire     NaN    309  39      52       43       60       50
# 4  5  Charmeleon   Fire     NaN    405  58      64       58       80       65
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     65           1      False
# 4     80           1      False

# %%
df.tail()
# Out:
#        #                 Name   Type 1  Type 2  Total   HP  Attack  Defense  \
# 737  738              Zygarde   Dragon  Ground    600  108     100      121
# 738  739              Diancie     Rock   Fairy    600   50     100      150
# 739  740  HoopaHoopa Confined  Psychic   Ghost    600   80     110       60
# 740  741   HoopaHoopa Unbound  Psychic    Dark    680   80     160       60
# 741  742            Volcanion     Fire   Water    600   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 737       81       95     95           6       True
# 738      100      150     50           6       True
# 739      150      130     70           6       True
# 740      170      130     80           6       True
# 741      130       90     70           6       True

# %%
df.head(6)
# Out:
#    #        Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2  3    Venusaur  Grass  Poison    525  80      82       83      100      100
# 3  4  Charmander   Fire     NaN    309  39      52       43       60       50
# 4  5  Charmeleon   Fire     NaN    405  58      64       58       80       65
# 5  6   Charizard   Fire  Flying    534  78      84       78      109       85
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     65           1      False
# 4     80           1      False
# 5    100           1      False

# %%
df.tail(2)
# Out:
#        #                Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 740  741  HoopaHoopa Unbound  Psychic   Dark    680  80     160       60
# 741  742           Volcanion     Fire  Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 740      170      130     80           6       True
# 741      130       90     70           6       True

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 742 entries, 0 to 741
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           742 non-null    int64
#  1   Name        742 non-null    object
#  2   Type 1      742 non-null    object
#  3   Type 2      368 non-null    object
#  4   Total       742 non-null    int64
#  5   HP          742 non-null    int64
#  6   Attack      742 non-null    int64
#  7   Defense     742 non-null    int64
#  8   Sp. Atk     742 non-null    int64
#  9   Sp. Def     742 non-null    int64
#  10  Speed       742 non-null    int64
#  11  Generation  742 non-null    int64
#  12  Legendary   742 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 70.4+ KB

# %%
df.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  742.000000  742.00000  742.000000  742.000000  742.000000  742.000000
# mean   371.500000  422.71159   68.699461   75.803235   71.439353   70.113208
# std    214.341239  111.89932   25.979645   29.657225   29.467766   29.979536
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    186.250000  325.00000   50.000000   55.000000   50.000000   45.250000
# 50%    371.500000  430.00000   65.000000   75.000000   67.000000   65.000000
# 75%    556.750000  500.00000   80.000000   95.000000   89.750000   90.000000
# max    742.000000  720.00000  255.000000  180.000000  230.000000  180.000000
#
#           Sp. Def       Speed  Generation
# count  742.000000  742.000000  742.000000
# mean    70.088949   66.567385    3.358491
# std     27.308952   27.899185    1.660302
# min     20.000000    5.000000    1.000000
# 25%     50.000000   45.000000    2.000000
# ...

# %%
df.describe().transpose()
# Out:
#             count        mean         std    min     25%    50%     75%    max
# #           742.0  371.500000  214.341239    1.0  186.25  371.5  556.75  742.0
# Total       742.0  422.711590  111.899320  180.0  325.00  430.0  500.00  720.0
# HP          742.0   68.699461   25.979645    1.0   50.00   65.0   80.00  255.0
# Attack      742.0   75.803235   29.657225    5.0   55.00   75.0   95.00  180.0
# Defense     742.0   71.439353   29.467766    5.0   50.00   67.0   89.75  230.0
# Sp. Atk     742.0   70.113208   29.979536   10.0   45.25   65.0   90.00  180.0
# Sp. Def     742.0   70.088949   27.308952   20.0   50.00   65.0   85.00  230.0
# Speed       742.0   66.567385   27.899185    5.0   45.00   65.0   86.75  180.0
# Generation  742.0    3.358491    1.660302    1.0    2.00    3.0    5.00    6.0

# %%
len(df)
# Out:
# 742

# %%
df.index
# Out:
# RangeIndex(start=0, stop=742, step=1)

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df["Name"]
# Out:
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3               Charmander
# 4               Charmeleon
#               ...
# 737                Zygarde
# 738                Diancie
# 739    HoopaHoopa Confined
# 740     HoopaHoopa Unbound
# 741              Volcanion
# Name: Name, Length: 742, dtype: object

# %%
df["Attack"]
# Out:
# 0       49
# 1       62
# 2       82
# 3       52
# 4       64
#       ...
# 737    100
# 738    100
# 739    110
# 740    160
# 741    110
# Name: Attack, Length: 742, dtype: int64

# %%
type(df["Defense"])
# Out:
# pandas.core.series.Series

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df[["Name","Type 1"]]
# Out:
#                     Name   Type 1
# 0              Bulbasaur    Grass
# 1                Ivysaur    Grass
# 2               Venusaur    Grass
# 3             Charmander     Fire
# 4             Charmeleon     Fire
# ..                   ...      ...
# 737              Zygarde   Dragon
# 738              Diancie     Rock
# 739  HoopaHoopa Confined  Psychic
# 740   HoopaHoopa Unbound  Psychic
# 741            Volcanion     Fire
#
# [742 rows x 2 columns]

# %% [markdown]
# ---
# ---

# %% [markdown]
# ### Sütun Ekleme

# %%
df["Total Atk"] = df["Attack"] + df["Sp. Atk"]
df.head()
# Out:
#    #        Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2  3    Venusaur  Grass  Poison    525  80      82       83      100      100
# 3  4  Charmander   Fire     NaN    309  39      52       43       60       50
# 4  5  Charmeleon   Fire     NaN    405  58      64       58       80       65
#
#    Speed  Generation  Legendary  Total Atk
# 0     45           1      False        114
# 1     60           1      False        142
# 2     80           1      False        182
# 3     65           1      False        112
# 4     80           1      False        144

# %%
df["hp ratio %"] = round(100 * df["HP"] / df["Defense"], 2)
df.head()
# Out:
#    #        Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2  3    Venusaur  Grass  Poison    525  80      82       83      100      100
# 3  4  Charmander   Fire     NaN    309  39      52       43       60       50
# 4  5  Charmeleon   Fire     NaN    405  58      64       58       80       65
#
#    Speed  Generation  Legendary  Total Atk  hp ratio %
# 0     45           1      False        114       91.84
# 1     60           1      False        142       95.24
# 2     80           1      False        182       96.39
# 3     65           1      False        112       90.70
# 4     80           1      False        144      100.00

# %%
# df["hp ratio %"] = round(df["hp ratio %"], 2)
# bu da makbuldür

# %% [markdown]
# ___
# ___

# %% [markdown]
# ### .drop()

# %%
# df.drop("hp ratio %")
# Axis yok

# %%
# help(df.drop)

# %%
df.drop("hp ratio %", axis=1).head()
# Out:
#    #        Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2  3    Venusaur  Grass  Poison    525  80      82       83      100      100
# 3  4  Charmander   Fire     NaN    309  39      52       43       60       50
# 4  5  Charmeleon   Fire     NaN    405  58      64       58       80       65
#
#    Speed  Generation  Legendary  Total Atk
# 0     45           1      False        114
# 1     60           1      False        142
# 2     80           1      False        182
# 3     65           1      False        112
# 4     80           1      False        144

# %%
df.head()
# Hala burada
# Out:
#    #        Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2  3    Venusaur  Grass  Poison    525  80      82       83      100      100
# 3  4  Charmander   Fire     NaN    309  39      52       43       60       50
# 4  5  Charmeleon   Fire     NaN    405  58      64       58       80       65
#
#    Speed  Generation  Legendary  Total Atk  hp ratio %
# 0     45           1      False        114       91.84
# 1     60           1      False        142       95.24
# 2     80           1      False        182       96.39
# 3     65           1      False        112       90.70
# 4     80           1      False        144      100.00

# %%
df = df.drop("hp ratio %", axis=1)

# %%
df.head()
# Out:
#    #        Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2  3    Venusaur  Grass  Poison    525  80      82       83      100      100
# 3  4  Charmander   Fire     NaN    309  39      52       43       60       50
# 4  5  Charmeleon   Fire     NaN    405  58      64       58       80       65
#
#    Speed  Generation  Legendary  Total Atk
# 0     45           1      False        114
# 1     60           1      False        142
# 2     80           1      False        182
# 3     65           1      False        112
# 4     80           1      False        144

# %%
df.drop("Total Atk", axis=1, inplace=True)
# Arka arkaya 2 kere çalıştırmayı dene ve sence hata ne onu söyle

# %%
df.head()
# Out:
#    #        Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2  3    Venusaur  Grass  Poison    525  80      82       83      100      100
# 3  4  Charmander   Fire     NaN    309  39      52       43       60       50
# 4  5  Charmeleon   Fire     NaN    405  58      64       58       80       65
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     65           1      False
# 4     80           1      False

# %%
df.drop([4], axis= 0).head()
# Out:
#    #        Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2  3    Venusaur  Grass  Poison    525  80      82       83      100      100
# 3  4  Charmander   Fire     NaN    309  39      52       43       60       50
# 5  6   Charizard   Fire  Flying    534  78      84       78      109       85
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     65           1      False
# 5    100           1      False

# %%
df.drop([3]).head()
# Out:
#    #        Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2  3    Venusaur  Grass  Poison    525  80      82       83      100      100
# 4  5  Charmeleon   Fire     NaN    405  58      64       58       80       65
# 5  6   Charizard   Fire  Flying    534  78      84       78      109       85
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 4     80           1      False
# 5    100           1      False

# %% [markdown]
# ____
# ____

# %% [markdown]
# ### .append()

# %%
kumay = df.iloc[619]
kumay
# Out:
# #                 620
# Name          Lampent
# Type 1          Ghost
# Type 2           Fire
# Total             370
# HP                 60
# Attack             40
# Defense            60
# Sp. Atk            95
# Sp. Def            60
# Speed              55
# Generation          5
# Legendary       False
# Name: 619, dtype: object

# %%
type(kumay)
# Out:
# pandas.core.series.Series

# %%
df.tail()
# Out:
#        #                 Name   Type 1  Type 2  Total   HP  Attack  Defense  \
# 737  738              Zygarde   Dragon  Ground    600  108     100      121
# 738  739              Diancie     Rock   Fairy    600   50     100      150
# 739  740  HoopaHoopa Confined  Psychic   Ghost    600   80     110       60
# 740  741   HoopaHoopa Unbound  Psychic    Dark    680   80     160       60
# 741  742            Volcanion     Fire   Water    600   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 737       81       95     95           6       True
# 738      100      150     50           6       True
# 739      150      130     70           6       True
# 740      170      130     80           6       True
# 741      130       90     70           6       True

# %%
df.append(kumay).tail()
# Out:
#        #                 Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 738  739              Diancie     Rock  Fairy    600  50     100      150
# 739  740  HoopaHoopa Confined  Psychic  Ghost    600  80     110       60
# 740  741   HoopaHoopa Unbound  Psychic   Dark    680  80     160       60
# 741  742            Volcanion     Fire  Water    600  80     110      120
# 619  620              Lampent    Ghost   Fire    370  60      40       60
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 738      100      150     50           6       True
# 739      150      130     70           6       True
# 740      170      130     80           6       True
# 741      130       90     70           6       True
# 619       95       60     55           5      False

# %%
df.tail(3)
# Out:
#        #                 Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 739  740  HoopaHoopa Confined  Psychic  Ghost    600  80     110       60
# 740  741   HoopaHoopa Unbound  Psychic   Dark    680  80     160       60
# 741  742            Volcanion     Fire  Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 739      150      130     70           6       True
# 740      170      130     80           6       True
# 741      130       90     70           6       True

# %%
df_2 = df.iloc[269:273]
df_2
# Out:
#        #      Name Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 269  270    Lombre  Water  Grass    340  60      50       50       60
# 270  271  Ludicolo  Water  Grass    480  80      70       70       90
# 271  272    Seedot  Grass    NaN    220  40      40       50       30
# 272  273   Nuzleaf  Grass   Dark    340  70      70       40       60
#
#      Sp. Def  Speed  Generation  Legendary
# 269       70     50           3      False
# 270      100     70           3      False
# 271       30     30           3      False
# 272       40     60           3      False

# %%
df.append(df_2).tail()
# Out:
#        #       Name Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 741  742  Volcanion   Fire  Water    600  80     110      120      130
# 269  270     Lombre  Water  Grass    340  60      50       50       60
# 270  271   Ludicolo  Water  Grass    480  80      70       70       90
# 271  272     Seedot  Grass    NaN    220  40      40       50       30
# 272  273    Nuzleaf  Grass   Dark    340  70      70       40       60
#
#      Sp. Def  Speed  Generation  Legendary
# 741       90     70           6       True
# 269       70     50           3      False
# 270      100     70           3      False
# 271       30     30           3      False
# 272       40     60           3      False

# %% [markdown]
# Dipnot olarak belirteyim. Normalde iki dataframe'i birbirine eklerken df.append() yerine pd.concat() şeklinde birleştirmelisiniz.
#
# pd.concat() metodunu bir kaç ders sonra göreceksiniz.
#
# Ben burada sadece göstermek için böyle yaptım. Alışmayın.
#
# **Alışmış kudurmuştan beterdir.**

# %% [markdown]
# ___
# ___

# %% [markdown]
# ### DataFrame İndex Operasyonları

# %%
df.set_index("#").head()
# Out:
#          Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 1   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 2     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 3    Venusaur  Grass  Poison    525  80      82       83      100      100
# 4  Charmander   Fire     NaN    309  39      52       43       60       50
# 5  Charmeleon   Fire     NaN    405  58      64       58       80       65
#
#    Speed  Generation  Legendary
# #
# 1     45           1      False
# 2     60           1      False
# 3     80           1      False
# 4     65           1      False
# 5     80           1      False

# %%
df.reset_index().head()
# Out:
#    index  #        Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0      0  1   Bulbasaur  Grass  Poison    318  45      49       49       65
# 1      1  2     Ivysaur  Grass  Poison    405  60      62       63       80
# 2      2  3    Venusaur  Grass  Poison    525  80      82       83      100
# 3      3  4  Charmander   Fire     NaN    309  39      52       43       60
# 4      4  5  Charmeleon   Fire     NaN    405  58      64       58       80
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3       50     65           1      False
# 4       65     80           1      False

# %%
df.iloc[2]
# Out:
# #                    3
# Name          Venusaur
# Type 1           Grass
# Type 2          Poison
# Total              525
# HP                  80
# Attack              82
# Defense             83
# Sp. Atk            100
# Sp. Def            100
# Speed               80
# Generation           1
# Legendary        False
# Name: 2, dtype: object

# %%
df.loc[9]
# Out:
# #                   10
# Name          Caterpie
# Type 1             Bug
# Type 2             NaN
# Total              195
# HP                  45
# Attack              30
# Defense             35
# Sp. Atk             20
# Sp. Def             20
# Speed               45
# Generation           1
# Legendary        False
# Name: 9, dtype: object

# %%
df.loc[9:11]
# isim temelli çalışır
# Out:
#      #        Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 9   10    Caterpie    Bug     NaN    195  45      30       35       20
# 10  11     Metapod    Bug     NaN    205  50      20       55       25
# 11  12  Butterfree    Bug  Flying    395  60      45       50       90
#
#     Sp. Def  Speed  Generation  Legendary
# 9        20     45           1      False
# 10       25     30           1      False
# 11       80     70           1      False

# %%
df.iloc[25:35]
# int temelli çalışır.
# Out:
#      #       Name    Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 25  26     Raichu  Electric     NaN    485  60      90       55       90
# 26  27  Sandshrew    Ground     NaN    300  50      75       85       20
# 27  28  Sandslash    Ground     NaN    450  75     100      110       45
# 28  29   Nidoran♀    Poison     NaN    275  55      47       52       40
# 29  30   Nidorina    Poison     NaN    365  70      62       67       55
# 30  31  Nidoqueen    Poison  Ground    505  90      92       87       75
# 31  32   Nidoran♂    Poison     NaN    273  46      57       40       40
# 32  33   Nidorino    Poison     NaN    365  61      72       57       55
# 33  34   Nidoking    Poison  Ground    505  81     102       77       85
# 34  35   Clefairy     Fairy     NaN    323  70      45       48       60
#
#     Sp. Def  Speed  Generation  Legendary
# 25       80    110           1      False
# 26       30     40           1      False
# ...

# %%
df.head(2)
# Out:
#    #       Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1  Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2    Ivysaur  Grass  Poison    405  60      62       63       80       80
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False

# %%
df = df.set_index("Name")

# %%
df
# Out:
#                        #   Type 1  Type 2  Total   HP  Attack  Defense  \
# Name
# Bulbasaur              1    Grass  Poison    318   45      49       49
# Ivysaur                2    Grass  Poison    405   60      62       63
# Venusaur               3    Grass  Poison    525   80      82       83
# Charmander             4     Fire     NaN    309   39      52       43
# Charmeleon             5     Fire     NaN    405   58      64       58
# ...                  ...      ...     ...    ...  ...     ...      ...
# Zygarde              738   Dragon  Ground    600  108     100      121
# Diancie              739     Rock   Fairy    600   50     100      150
# HoopaHoopa Confined  740  Psychic   Ghost    600   80     110       60
# HoopaHoopa Unbound   741  Psychic    Dark    680   80     160       60
# Volcanion            742     Fire   Water    600   80     110      120
#
#                      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# Name
# ...

# %%
df.loc["Lugia"]
# Out:
# #                 248
# Type 1        Psychic
# Type 2         Flying
# Total             680
# HP                106
# Attack             90
# Defense           130
# Sp. Atk            90
# Sp. Def           154
# Speed             110
# Generation          2
# Legendary        True
# Name: Lugia, dtype: object

# %%
df.loc[["Abra","Vulpix","Eevee"]]
# Out:
#           #   Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# Abra     63  Psychic    NaN    310  25      20       15      105       55
# Vulpix   37     Fire    NaN    299  38      41       40       50       65
# Eevee   132   Normal    NaN    325  55      55       50       45       65
#
#         Speed  Generation  Legendary
# Name
# Abra       90           1      False
# Vulpix     65           1      False
# Eevee      55           1      False

# %%
# df.iloc["Gengar"]

# %%
df = df.reset_index()
df.head()
# Out:
#          Name  # Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0   Bulbasaur  1  Grass  Poison    318  45      49       49       65       65
# 1     Ivysaur  2  Grass  Poison    405  60      62       63       80       80
# 2    Venusaur  3  Grass  Poison    525  80      82       83      100      100
# 3  Charmander  4   Fire     NaN    309  39      52       43       60       50
# 4  Charmeleon  5   Fire     NaN    405  58      64       58       80       65
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     65           1      False
# 4     80           1      False

# %%
df
# Out:
#                     Name    #   Type 1  Type 2  Total   HP  Attack  Defense  \
# 0              Bulbasaur    1    Grass  Poison    318   45      49       49
# 1                Ivysaur    2    Grass  Poison    405   60      62       63
# 2               Venusaur    3    Grass  Poison    525   80      82       83
# 3             Charmander    4     Fire     NaN    309   39      52       43
# 4             Charmeleon    5     Fire     NaN    405   58      64       58
# ..                   ...  ...      ...     ...    ...  ...     ...      ...
# 737              Zygarde  738   Dragon  Ground    600  108     100      121
# 738              Diancie  739     Rock   Fairy    600   50     100      150
# 739  HoopaHoopa Confined  740  Psychic   Ghost    600   80     110       60
# 740   HoopaHoopa Unbound  741  Psychic    Dark    680   80     160       60
# 741            Volcanion  742     Fire   Water    600   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# ---
# ---

# %% [markdown]
# # **https://www.youtube.com/watch?v=fxrRpveHH0U**
